# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarAliM/Matematicas_y_Ciencia_de_Datos_2024/blob/main/Fase_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerías requeridas
import pandas as pd
registro = pd.read_excel('A01736492_Actividad2_Registro.xlsx')
registro
# Out:
#     Fecha (dd/mm/aa)   Momento  \
# 0         2021-02-15  Desayuno
# 1         2021-02-15  Desayuno
# 2         2021-02-15  Desayuno
# 3         2021-02-15    Comida
# 4         2021-02-15    Comida
# ..               ...       ...
# 350       2024-05-07    Comida
# 351       2024-05-08    Comida
# 352       2024-05-09     Snack
# 353       2024-05-10     Snack
# 354       2024-05-11      Cena
#
#                                        Nombre alimento  Calorías (kcal)  \
# 0                                         Carne de Res            0.135
# 1                                         Carne de Res            0.135
# 2                                     Pechuga de Pollo            0.195
# 3                                         Carne de Res            0.135
# 4                                         Carne de Res            0.135
# ..                                                 ...              ...
# 350                      Salteado de tofu con verduras          450.000
# 351  Pollo o pescado a la parrilla con arroz integr...          450.000
# 352                Salmón con quinoa y verduras asadas          150.000
# 353                            Sopa de frijoles negros          150.000
# 354                                   Sopa de lentejas          250.000
#
#      Carbohidratos (g)  Lípidos/grasas (g)  Proteína (g)  Sodio (mg)  \
# 0                  0.0                4.62         21.91        57.0
# 1                  0.0                4.62         21.91        57.0
# 2                  0.0                7.72         29.55       393.0
# 3                  0.0                4.62         21.91        57.0
# 4                  0.0                4.62         21.91        57.0
# ..                 ...                 ...           ...         ...
# 350               30.0               20.00         25.00       325.0
# 351               30.0               25.00         30.00       325.0
# 352               25.0               25.00         30.00       375.0
# 353               25.0               15.00         20.00       200.0
# 354               15.0               10.00         20.00       200.0
#
#                                                 Fuente  Unnamed: 9  \
# 0    https://www.fatsecret.com.mx/calorías-nutrició...         NaN
# 1    https://www.fatsecret.com.mx/calorías-nutrició...         NaN
# 2    https://www.fatsecret.com.mx/calorías-nutrició...         NaN
# 3    https://www.fatsecret.com.mx/calorías-nutrició...         NaN
# 4    https://www.fatsecret.com.mx/calorías-nutrició...         NaN
# ..                                                 ...         ...
# 350                                                NaN         NaN
# 351                                                NaN         NaN
# 352                                                NaN         NaN
# 353                                                NaN         NaN
# 354                                                NaN         NaN
#
#              Unnamed: 10                                Unnamed: 11
# 0             Matrícula:                                  A01736492
# 1                Nombre:                   Oscar Ali Morales Juárez
# 2                    NaN                                        NaN
# 3    Momento de consumo:  Indicar el momento de consumo en la tabla
# 4                    NaN                                   Desayuno
# ..                   ...                                        ...
# 350                  NaN                                        NaN
# 351                  NaN                                        NaN
# 352                  NaN                                        NaN
# 353                  NaN                                        NaN
# 354                  NaN                                        NaN
#
# [355 rows x 12 columns]

# %%
registro.columns
# Out:
# Index(['Fecha (dd/mm/aa)', 'Momento', 'Nombre alimento', 'Calorías (kcal)',
#        'Carbohidratos (g)', 'Lípidos/grasas (g)', 'Proteína (g)', 'Sodio (mg)',
#        'Fuente', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
datos = registro[["Fecha (dd/mm/aa)","Calorías (kcal)"]]

# %%
suma_calorías = datos["Calorías (kcal)"].sum()
suma_calorías # despliega el total de calorias
# Out:
# 32043.387000000002

# %%
días = datos["Fecha (dd/mm/aa)"].nunique()
días # despliega el total de días unicos
# Out:
# 82

# %%
calorías_promedio = suma_calorías/días # total de calorías consumidas entre el número de días que tomó consumirlas
print("Tu promedio de calorías consumidas en", días,"días es:", calorías_promedio)
# Out:
# Tu promedio de calorías consumidas en 82 días es: 390.77301219512196

# %%
genero= "Hombre"
altura= 170
peso= 80
edad= 21

if(genero == "Mujer"):
   calorías_requeridas = 655+(9.56*peso)+(1.85*altura)-(4.68*edad) # fórmula para estimar calorías requeridas en mujer

elif(genero == "Hombre"):
  calorías_requeridas = 66.5+(13.75*peso)+(5*altura)-(6.8*edad) # fórmula para estimar calorías requeridas en hombre

print("Con base en tus datos, tu consumo de calorías al día debe ser de:", calorías_requeridas)
# Out:
# Con base en tus datos, tu consumo de calorías al día debe ser de: 1873.7

# %%
diferencia=calorías_promedio-calorías_requeridas

efecto_anual = diferencia * 450/3500 * 365 /1000 # realiza la proporción, se multiplica por 365 (días) y se divide entre 1000 (gramos) para obtener kilogramos

print("Si continuas con el consumo calórico actual, en un año tu cambio de masa corporal sería aproximadamente de:",efecto_anual,"kg")
# Out:
# Si continuas con el consumo calórico actual, en un año tu cambio de masa corporal sería aproximadamente de: -69.59164507055749 kg
