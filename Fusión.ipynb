# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarAliM/Matematicas_y_Ciencia_de_Datos_2024/blob/main/Fusi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerías requeridas
import pandas as pd
registro = pd.read_excel('surveys.xlsx', index_col=0)
registro=registro.rename(columns={"month":"mes","day":"día","year":"año","plot_id":"avistamiento","species_id": "código","sex":"sexo","hindfoot_length":"patitas","weight":"peso"})
registro
# Out:
#            mes  día   año  avistamiento código sexo  patitas  peso
# record_id
# 1            7   16  1977             2     NL    M     32.0   NaN
# 2            7   16  1977             3     NL    M     33.0   NaN
# 3            7   16  1977             2     DM    F     37.0   NaN
# 4            7   16  1977             7     DM    M     36.0   NaN
# 5            7   16  1977             3     DM    M     35.0   NaN
# ...        ...  ...   ...           ...    ...  ...      ...   ...
# 35545       12   31  2002            15     AH  NaN      NaN   NaN
# 35546       12   31  2002            15     AH  NaN      NaN   NaN
# 35547       12   31  2002            10     RM    F     15.0  14.0
# 35548       12   31  2002             7     DO    M     36.0  51.0
# 35549       12   31  2002             5    NaN  NaN      NaN   NaN
#
# [35549 rows x 8 columns]

# %%
registro.columns
# Out:
# Index(['mes', 'día', 'año', 'avistamiento', 'código', 'sexo', 'patitas',
#        'peso'],
#       dtype='object')

# %%
registro.dtypes
# Out:
# mes               int64
# día               int64
# año               int64
# avistamiento      int64
# código           object
# sexo             object
# patitas         float64
# peso            float64
# dtype: object

# %%
registro.shape
# Out:
# (35549, 8)

# %%
pd.unique(registro['código'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
len(pd.unique(registro['código']))
# Out:
# 49

# %%
registro['código'].nunique()
# Out:
# 48

# %%
sitios=pd.unique(registro['avistamiento'])
sitios
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
len(sitios)
# Out:
# 24

# %%
#Paso alternativo para encontrar la cantidad de datos distintos que tiene una columna
registro['avistamiento'].nunique()
# Out:
# 24

# %%
registro['peso'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: peso, dtype: float64

# %%
registro.groupby('sexo').mean("peso")
# Out:
#            mes        día          año  avistamiento    patitas       peso
# sexo
# F     6.587253  15.880943  1990.644997     11.440854  28.836780  42.170555
# M     6.396184  16.078799  1990.480401     11.098282  29.709578  42.995379

# %%
agrupación1=registro.groupby(['avistamiento','sexo'])
agrupación1.mean("peso")
# Out:
#                         mes        día          año    patitas       peso
# avistamiento sexo
# 1            F     6.597877  15.338443  1990.933962  31.733911  46.311138
#              M     6.121461  15.905936  1990.091324  34.302770  55.950560
# 2            F     6.426804  16.288660  1990.449485  30.161220  52.561845
#              M     6.340035  15.440559  1990.756119  30.353760  51.391382
# 3            F     6.610302  15.993281  1992.013438  23.774044  31.215349
#              M     6.277381  16.271429  1992.275000  23.833744  34.163241
# 4            F     6.447248  15.608945  1990.235092  33.249102  46.818824
#              M     6.436893  16.303883  1991.000971  34.097959  48.888119
# 5            F     6.142315  15.722960  1986.485769  28.921844  40.974806
#              M     6.194539  15.703072  1986.817406  29.694794  40.708551
# 6            F     6.640434  15.947083  1991.579376  26.981322  36.352288
# ...

# %%
len(registro[pd.isnull(registro.peso)])
# Out:
# 3266

# %%
registro1=registro.copy()
registro1['peso']=registro1['peso'].fillna(42.67)
registro1['peso'].mean()
# Out:
# 42.67220512531998

# %%
registro_primeras=registro.head(6)
registro_ultimas=registro.tail(5)
registro_ultimas=registro_ultimas.reset_index(drop=True)
ap_vertical=pd.concat([registro_primeras,registro_ultimas],axis=0) #eje 0 es hacia abajo, eje 1 es el de las x
ap_vertical.reset_index()
# Out:
#     index  mes  día   año  avistamiento código sexo  patitas  peso
# 0       1    7   16  1977             2     NL    M     32.0   NaN
# 1       2    7   16  1977             3     NL    M     33.0   NaN
# 2       3    7   16  1977             2     DM    F     37.0   NaN
# 3       4    7   16  1977             7     DM    M     36.0   NaN
# 4       5    7   16  1977             3     DM    M     35.0   NaN
# 5       6    7   16  1977             1     PF    M     14.0   NaN
# 6       0   12   31  2002            15     AH  NaN      NaN   NaN
# 7       1   12   31  2002            15     AH  NaN      NaN   NaN
# 8       2   12   31  2002            10     RM    F     15.0  14.0
# 9       3   12   31  2002             7     DO    M     36.0  51.0
# 10      4   12   31  2002             5    NaN  NaN      NaN   NaN

# %%
registros = pd.read_excel('surveys.xlsx')
registros.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
especies=pd.read_excel('species.xlsx')
especies.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
fusion=pd.merge(left=registros, right=especies,
                left_on='species_id',right_on='species_id')
fusion.sample(10)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 8860       22432      6   28  1995       11         DM    M             36.0
# 31759      18834      7   12  1991       19         SF    M             26.0
# 1273          37      7   17  1977       11         DM    F             35.0
# 26566      10372      5   23  1985       14         OL    F             20.0
# 13932      13848      1   23  1988       12         PE    F             21.0
# 33472      32310      7   22  2001        8         PB    F             26.0
# 10197      27524      2    1  1998       14         DM    M             35.0
# 30697      12832      5   28  1987       15         AH  NaN              NaN
# 22288      29777      6   13  1999        4         OT    F             20.0
# 33052      30983      7    1  2000       24         PB    M             26.0
#
#        weight             genus      species    taxa
# 8860     47.0         Dipodomys     merriami  Rodent
# ...
